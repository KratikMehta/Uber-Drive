# %%
# %matplotlib --list
# Out:
# Available matplotlib backends: ['tk', 'gtk', 'gtk3', 'gtk4', 'wx', 'qt4', 'qt5', 'qt6', 'qt', 'osx', 'nbagg', 'notebook', 'agg', 'svg', 'pdf', 'ps', 'inline', 'ipympl', 'widget']

# %% [markdown]
# #### Instructions:
#
# For all questions after 10th, Please only use the data specified in the note given just below the question
# You need to add answers in the same file i.e. PDS_UberDriveProject_Questions.ipynb' and rename that file as 'Name_Date.ipynb'.You can mention the date on which you will be uploading/submitting the file.For e.g. if you plan to submit your assignment on 1st January 2021, you can rename the file as 'STUDENTNAME_01-Jan-2021'

# %% [markdown]
# # Load the necessary libraries. Import and load the dataset with a name uber_drives .

# %%
import matplotlib_inline
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# %precision 3

matplotlib_inline.backend_inline.set_matplotlib_formats('pdf', 'svg')
sns.set()

# %%
# Get the Data
uber = pd.read_csv('uberdrives.csv')

# %%
uber.style.to_html()
# Out:
# '<style type="text/css">\n</style>\n<table id="T_be74e">\n  <thead>\n    <tr>\n      <th class="blank level0" >&nbsp;</th>\n      <th id="T_be74e_level0_col0" class="col_heading level0 col0" >START_DATE*</th>\n      <th id="T_be74e_level0_col1" class="col_heading level0 col1" >END_DATE*</th>\n      <th id="T_be74e_level0_col2" class="col_heading level0 col2" >CATEGORY*</th>\n      <th id="T_be74e_level0_col3" class="col_heading level0 col3" >START*</th>\n      <th id="T_be74e_level0_col4" class="col_heading level0 col4" >STOP*</th>\n      <th id="T_be74e_level0_col5" class="col_heading level0 col5" >MILES*</th>\n      <th id="T_be74e_level0_col6" class="col_heading level0 col6" >PURPOSE*</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th id="T_be74e_level0_row0" class="row_heading level0 row0" >0</th>\n      <td id="T_be74e_row0_col0" class="data row0 col0" >01-01-2016 21:11</td>\n      <td id="T_be74e_row0_col1" class="data row0 col1" >01-01-2016 21:17</td>\n      <td id="T_be74e_row0_col2" class="data row0 col2" >Business</td>\n      <td id="T_be74e_row0_col3" class="data row0 col3" >Fort Pierce</td>\n      <td id="T_be74e_row0_col4" class="data row0 col4" >Fort Pierce</td>\n      <td id="T_be74e_row0_col5" class="data row0 col5" >5.100000</td>\n      <td id="T_be74e_row0_col6" class="data row0 col6" >Meal/Entertain</td>\n    </tr>\n    <tr>\n      <th id="T_be74e_level0_row1" class="row_heading level0 row1" >1</th>\n      <td id="T_be74e_row1_col0" class="data row1 col0" >01-02-2016 01:25</td>\n      <td id="T_be74e_row1_col1" class="data row1 col1" >01-02-2016 01:37</td>\n      <td id="T_be74e_row1_col2" class="data row1 col2" >Business</td>\n      <td id="T_be74e_row1_col3" class="data row1 col3" >Fort Pierce</td>\n      <td id="T_be74e_row1_col4" class="data row1 col4" >Fort Pierce</td>\n      <td id="T_be74e_row1_col5" class="data row1 col5" >5.000000</td>\n      <td id="T_be74e_row1_col6" class="data row1 col6" >nan</td>\n    </tr>\n    <tr>\n      <th id="T_be74e_level0_row2" class="row_heading level0 row2" >2</th>\n      <td id="T_be74e_row2_col0" class="data row2 col0" >01-02-2016 20:25</td>\n      <td id="T_be74e_row2_col1" class="data row2 col1" >01-02-2016 20:38</td>\n      <td id="T_be74e_row2_col2" class="data row2 col2" >Business</td>\n      <td id="T_be74e_row2_col3" class="data row2 col3" >Fort Pierce</td>\n      <td id="T_be74e_row2_col4" class="data row2 col4" >Fort Pierce</td>\n      <td id="T_be74e_row2_col5" class="data row2 col5" >4.800000</td>\n      <td id="T_be74e_row2_col6" class="data row2 col6" >Errand/Supplies</td>\n    </tr>\n    <tr>\n      <th id="T_be74e_level0_row3" class="row_heading level0 row3" >3</th>\n      <td id="T_be74e_row3_col0" class="data row3 col0" >01-05-2016 17:31</td>\n      <td id="T_be74e_row3_col1" class="data row3 col1" >01-05-2016 17:45</td>\n      <td id="T_be74e_row3_col2" class="data row3 col2" >Business</td>\n      <td id="T_be74e_row3_col3" class="data row3 col3" >Fort Pierce</td>\n      <td id="T_be74e_row3_col4" class="data row3 col4" >Fort Pierce</td>\n      <td id="T_be74e_row3_col5" class="data row3 col5" >4.700000</td>\n      <td id="T_be74e_row3_col6" class="data row3 col6" >Meeting</td>\n    </tr>\n    <tr>\n      <th id="T_be74e_level0_row4" class="row_heading level0 row4" >4</th>\n      <td id="T_be74e_row4_col0" class="data row4 col0" >01-06-2016 14:42</td>\n      <td id="T_be74e_row4_col1" class="data row4 col1" >01-06-2016 15:49</td>\n      <td id="T_be74e_row4_col2" class="data row4 col2" >Business</td>\n      <td id="T_be74e_row4_col3" class="data row4 col3" >Fort Pierce</td>\n      <td id="T_be74e_row4_col4" class="data row4 col4" >West Palm Beach</td>\n      <td id="T_be74e_row4_col5" class="data row4 col5" >63.700000</td>\n      <td id="T_be74e_row4_col6" class="data row4 col6" >Customer Visit</td>\n    </tr>\n    <tr>\n      <th id="T_be74e_level0_row5" class="row_heading level0 row5" >5</th>\n      <td id="T_be74e_row5_col0" class="data ...

# %% [markdown]
# ## Q1. Show the last 10 records of the dataset. (2 point)

# %%
uber.tail(10)

# %% [markdown]
# ## Q2. Show the first 10 records of the dataset. (2 points)

# %%
uber.head(10)
# Out:
#         START_DATE*         END_DATE* CATEGORY*           START*  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business      Fort Pierce
# 1  01-02-2016 01:25  01-02-2016 01:37  Business      Fort Pierce
# 2  01-02-2016 20:25  01-02-2016 20:38  Business      Fort Pierce
# 3  01-05-2016 17:31  01-05-2016 17:45  Business      Fort Pierce
# 4  01-06-2016 14:42  01-06-2016 15:49  Business      Fort Pierce
# 5  01-06-2016 17:15  01-06-2016 17:19  Business  West Palm Beach
# 6  01-06-2016 17:30  01-06-2016 17:35  Business  West Palm Beach
# 7  01-07-2016 13:27  01-07-2016 13:33  Business             Cary
# 8  01-10-2016 08:05  01-10-2016 08:25  Business             Cary
# 9  01-10-2016 12:17  01-10-2016 12:44  Business          Jamaica
#
#              STOP*  MILES*         PURPOSE*
# 0      Fort Pierce     5.1   Meal/Entertain
# 1      Fort Pierce     5.0              NaN
# 2      Fort Pierce     4.8  Errand/Supplies
# 3      Fort Pierce     4.7          Meeting
# 4  West Palm Beach    63.7   Customer Visit
# 5  West Palm Beach     4.3   Meal/Entertain
# 6       Palm Beach     7.1          Meeting
# 7             Cary     0.8          Meeting
# 8      Morrisville     8.3          Meeting
# 9         New York    16.5   Customer Visit

# %% [markdown]
# ## Q3. Show the dimension(number of rows and columns) of the dataset. (2 points)

# %%
print(
    f"There are {uber.shape[0]} rows and {uber.shape[1]} columns in the dataset."
)
# Out:
# There are 1155 rows and 7 columns in the dataset.

# %% [markdown]
# ## Q4. Show the size (Total number of elements) of the dataset. (2 points)

# %%
print(f"There are {uber.size} number of elements in the dataset.")
# Out:
# There are 8085 number of elements in the dataset.

# %% [markdown]
# ## Q5. Display the information about all the variables of the data set. What can you infer from the output?(1 +2 points)
#
# #### Hint: Information includes - Total number of columns,variable data-types, number of non-null values in a variable, and usage

# %%
uber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1155 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1155 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1155 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %% [markdown]
# From the above output we can infer that:
# 1. There are 7 variables(i.e. number of columns) in the dataset.
# 2. Out of the 7 variables, 6 of them are of objects data-type and 1 is of float data-type.
# 3. PURPOSE* is the only column that has null values.
# 4. The dataset is consuming more than 63.3 KB of memory.

# %% [markdown]
# ## Q6. Check for missing values. (2 points)
#
# ####  Note: Output should contain only one boolean value

# %%
bool(uber.isna().sum().sum())
# Out:
# True

# %% [markdown]
# The above output shows that the dataset contains missing values.

# %% [markdown]
# ## Q7. How many missing values are present in the entire dataset? (2 points)

# %%
uber.isna().sum()
# Out:
# START_DATE*      0
# END_DATE*        0
# CATEGORY*        0
# START*           0
# STOP*            0
# MILES*           0
# PURPOSE*       502
# dtype: int64

# %% [markdown]
# There are 502 missing values present in the dataset. All of these missing values are from the PURPOSE* column.

# %% [markdown]
# ## Q8. Get the summary of the original data. (2 points).
#
# #### Hint: Summary includes- Count,Mean, Std, Min, 25%,50%,75% and max

# %%
uber.describe()
# Out:
#             MILES*
# count  1155.000000
# mean     10.566840
# std      21.579106
# min       0.500000
# 25%       2.900000
# 50%       6.000000
# 75%      10.400000
# max     310.300000

# %% [markdown]
# As there is only 1 column with float data-type in the dataset, we only get the summary of that column in the above output.

# %% [markdown]
# ## Q9. Drop the missing values and store the data in a new dataframe (name it"df") (2-points)
#
# #### Note: Dataframe "df" will not contain any missing value

# %%
df = uber.dropna()

# %% [markdown]
# ## Q10. Check the information of the dataframe(df). (1 points)
#
# #### Hint: Information includes - Total number of columns,variable data-types, number of non-null values in a variable, and usage

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 653 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  653 non-null    object
#  1   END_DATE*    653 non-null    object
#  2   CATEGORY*    653 non-null    object
#  3   START*       653 non-null    object
#  4   STOP*        653 non-null    object
#  5   MILES*       653 non-null    float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 40.8+ KB

# %% [markdown]
# From the above output we can infer that:
# 1. There are 7 variables(i.e. number of columns) and 653 rows in the dataset.
# 2. Out of the 7 variables, 6 of them are of objects data-type and 1 is of float data-type.
# 3. The dataset does not have any null values.
# 4. The dataset is consuming more than 40.8 KB of memory.

# %% [markdown]
# ## Q11. Get the unique start locations. (2 points)
# #### Note: This question is based on the dataframe with no 'NA' values

# %%
print(df["START*"].unique())
# Out:
# ['Fort Pierce' 'West Palm Beach' 'Cary' 'Jamaica' 'New York' 'Elmhurst'
#  'Midtown' 'East Harlem' 'Flatiron District' 'Midtown East'
#  'Hudson Square' 'Lower Manhattan' "Hell's Kitchen" 'Downtown' 'Gulfton'
#  'Houston' 'Eagan Park' 'Morrisville' 'Durham' 'Farmington Woods'
#  'Lake Wellingborough' 'Fayetteville Street' 'Raleigh' 'Whitebridge'
#  'Hazelwood' 'Fairmont' 'Meredith Townes' 'Apex' 'Chapel Hill'
#  'Northwoods' 'Edgehill Farms' 'Eastgate' 'East Elmhurst'
#  'Long Island City' 'Katunayaka' 'Colombo' 'Nugegoda' 'Unknown Location'
#  'Islamabad' 'R?walpindi' 'Noorpur Shahan' 'Preston' 'Heritage Pines'
#  'Tanglewood' 'Waverly Place' 'Wayne Ridge' 'Westpark Place' 'East Austin'
#  'The Drag' 'South Congress' 'Georgian Acres' 'North Austin'
#  'West University' 'Austin' 'Katy' 'Sharpstown' 'Sugar Land' 'Galveston'
#  'Port Bolivar' 'Washington Avenue' 'Briar Meadow' 'Latta' 'Jacksonville'
#  'Lake Reams' 'Orlando' 'Kissimmee' 'Daytona Beach' 'Ridgeland' 'Florence'
#  'Meredith' 'Holly Springs' 'Chessington' 'Burtrose' 'Parkway' 'Mcvan'
#  'Capitol One' 'University District' 'Seattle' 'Redmond' 'Bellevue'
#  'San Francisco' 'Palo Alto' 'Sunnyvale' 'Newark' 'Menlo Park' 'Old City'
#  'Savon Height' 'Kilarney Woods' 'Townes at Everett Crossing'
#  'Huntington Woods' 'Weston' 'Seaport' 'Medical Centre' 'Rose Hill' 'Soho'
#  'Tribeca' 'Financial District' 'Oakland' 'Emeryville' 'Berkeley' 'Kenner'
#  'CBD' 'Lower Garden District' 'Storyville' 'New Orleans' 'Chalmette'
#  'Arabi' 'Pontchartrain Shores' 'Metairie' 'Summerwinds' 'Parkwood'
#  'Banner Elk' 'Boone' 'Stonewater' 'Lexington Park at Amberly'
#  'Winston Salem' 'Asheville' 'Topton' 'Renaissance' 'Santa Clara'
#  'Ingleside' 'West Berkeley' 'Mountain View' 'El Cerrito' 'Krendle Woods'
#  'Fuquay-Varina' 'Rawalpindi' 'Lahore' 'Karachi' 'Katunayake' 'Gampaha']

# %% [markdown]
# ## Q12. What is the total number of unique start locations? (2 points)
# #### Note: Use the original dataframe without dropping 'NA' values

# %%
print(
    f"There are {len(uber['START*'].unique())} unique start locations in the original dataset."
)
# Out:
# There are 176 unique start locations in the original dataset.

# %% [markdown]
# ## Q13. What is the total number of unique stop locations. (2 points)
# #### Note: Use the original dataframe without dropping 'NA' values.

# %%
print(
    f"There are {len(uber['STOP*'].unique())} unique stop locations in the original dataset."
)
# Out:
# There are 187 unique stop locations in the original dataset.

# %% [markdown]
# ## Q14. Display all Uber trips that has the starting point as San Francisco. (2 points)
# #### Note: Use the original dataframe without dropping the 'NA' values.

# %%
uber[uber["START*"] == "San Francisco"]
# Out:
#           START_DATE*         END_DATE* CATEGORY*         START*       STOP*  \
# 362  05-09-2016 14:39  05-09-2016 15:06  Business  San Francisco   Palo Alto
# 440   6/14/2016 16:09   6/14/2016 16:39  Business  San Francisco  Emeryville
# 836  10/19/2016 14:02  10/19/2016 14:31  Business  San Francisco    Berkeley
# 917  11-07-2016 19:17  11-07-2016 19:57  Business  San Francisco    Berkeley
# 919  11-08-2016 12:16  11-08-2016 12:49  Business  San Francisco    Berkeley
# 927  11-09-2016 18:40  11-09-2016 19:17  Business  San Francisco     Oakland
# 933  11-10-2016 15:17  11-10-2016 15:22  Business  San Francisco     Oakland
# 966  11/15/2016 20:44  11/15/2016 21:00  Business  San Francisco    Berkeley
#
#      MILES*         PURPOSE*
# 362    20.5  Between Offices
# 440    11.6          Meeting
# 836    10.8              NaN
# 917    13.2  Between Offices
# 919    11.3          Meeting
# 927    12.7   Customer Visit
# 933     9.9   Temporary Site
# 966    11.8   Temporary Site

# %% [markdown]
# ## Q15. What is the most popular starting point for the Uber drivers? (2 points)
# #### Note: Use the original dataframe without dropping the 'NA' values.
#
# #### Hint:Popular means the place that is visited the most

# %%
uber["START*"].value_counts()
# Out:
# Cary                 201
# Unknown Location     148
# Morrisville           85
# Whitebridge           68
# Islamabad             57
#                     ...
# Ridgeland              1
# Daytona Beach          1
# Sky Lake               1
# Sand Lake Commons      1
# Gampaha                1
# Name: START*, Length: 176, dtype: int64

# %% [markdown]
# "Cary" is the most popular starting point for the Uber drivers.

# %% [markdown]
# ## Q16. What is the most popular dropping point for the Uber drivers? (2 points)
# #### Note: Use the original dataframe without dropping the 'NA' values.
#
# #### Hint: Popular means the place that is visited the most

# %%
uber["STOP*"].value_counts()
# Out:
# Cary                 203
# Unknown Location     149
# Morrisville           84
# Whitebridge           65
# Islamabad             58
#                     ...
# Daytona Beach          1
# Sand Lake Commons      1
# Sky Lake               1
# Vista East             1
# Ilukwatta              1
# Name: STOP*, Length: 187, dtype: int64

# %% [markdown]
# "Cary" is the most popular dropping point for the Uber drivers.

# %% [markdown]
# ## Q17. What is the most frequent route taken by Uber drivers. (3 points)
# #### Note: This question is based on the new dataframe with no 'na' values.
# #### Hint-Print the most frequent route taken by Uber drivers (Route= combination of START & END points present in the Data set).

# %%
df["Route"] = df["START*"] + "-" + df["STOP*"]
df["Route"].value_counts()
# Out:
# C:\Users\mehta\AppData\Local\Temp\ipykernel_12876\457277127.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Route"] = df["START*"] + "-" + df["STOP*"]
# Cary-Morrisville                     52
# Morrisville-Cary                     51
# Cary-Cary                            44
# Unknown Location-Unknown Location    30
# Cary-Durham                          30
#                                      ..
# Galveston-Houston                     1
# Midtown-Washington Avenue             1
# Washington Avenue-Midtown             1
# Briar Meadow-Midtown                  1
# Gampaha-Ilukwatta                     1
# Name: Route, Length: 239, dtype: int64

# %% [markdown]
# Cary to Morrisville is the most frequent route taken by the Uber drivers.

# %% [markdown]
# ## Q18. Display all types of purposes for the trip in an array. (2 points)
# #### Note: This question is based on the new dataframe with no 'NA' values.

# %%
print(df["PURPOSE*"].unique())
# Out:
# ['Meal/Entertain' 'Errand/Supplies' 'Meeting' 'Customer Visit'
#  'Temporary Site' 'Between Offices' 'Charity ($)' 'Commute' 'Moving'
#  'Airport/Travel']

# %% [markdown]
# ## Q19. Plot a bar graph of Purpose vs Miles(Distance). What can you infer from the plot(2 +2 points)
# #### Note: Use the original dataframe without dropping the 'NA' values.
# #### Hint:You have to plot total/sum miles per purpose

# %%
purpose_miles = uber.groupby("PURPOSE*")["MILES*"].sum().reset_index()

fig, ax = plt.subplots()
sns.barplot(x="MILES*", y="PURPOSE*", data=purpose_miles, ax=ax);

# %% [markdown]
# From the plot it can be seen that total distance traveled is highest for Meeting purposes. Customer Visit rides also has large distance traveled. Charity has the least distance traveled. Maybe the passengers are ready to travel large distances for Meetings and Customer Visit.

# %% [markdown]
# ## Q20. Display a dataframe of Purpose and the total distance travelled for that particular Purpose. (3 points)
# #### Note: Use the original dataframe without dropping "NA" values

# %%
uber.groupby("PURPOSE*")["MILES*"].sum().reset_index()
# Out:
#           PURPOSE*  MILES*
# 0   Airport/Travel    16.5
# 1  Between Offices   197.0
# 2      Charity ($)    15.1
# 3          Commute   180.2
# 4   Customer Visit  2089.5
# 5  Errand/Supplies   508.0
# 6   Meal/Entertain   911.7
# 7          Meeting  2851.3
# 8           Moving    18.2
# 9   Temporary Site   523.7

# %% [markdown]
# ## Q21. Generate a plot showing count of trips vs category of trips. What can you infer from the plot (2 +1 points)
# #### Note: Use the original dataframe without dropping the 'NA' values.

# %%
fig, ax = plt.subplots()
sns.countplot(y="CATEGORY*", data=uber, ax=ax);

# %% [markdown]
# There are only two Categories. Most of the uber rides taken were for Business related work.

# %% [markdown]
# ## Q22. What percentage of Miles were clocked under Business Category and what percentage of Miles were clocked under Personal Category ? (3 points)
#
# ### Note:Use the original dataframe without dropping the 'NA' values.

# %%
business = uber.groupby("CATEGORY*")["MILES*"].sum().loc['Business']
personal = uber.groupby("CATEGORY*")["MILES*"].sum().loc['Personal']

business_perc = round(business / (business + personal) * 100, 2)
personal_perc = round(personal / (business + personal) * 100, 2)

print(
    f"The percentage of miles covered under Business category is {business_perc}%."
)
print(
    f"The percentage of miles covered under Personal category is {personal_perc}%."
)
# Out:
# The percentage of miles covered under Business category is 94.12%.
# The percentage of miles covered under Personal category is 5.88%.

# %% [markdown]
# ***THE END***
